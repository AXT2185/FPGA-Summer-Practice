# %% [markdown]
# # 在进行Sobel实验时遇到的一些问题以及解决方法

# %% [markdown]
# 由于本次时间相对比较紧迫，所以我们只能复现课堂上讲的几个实验以及对其中遇到的一些问题进行总结，以便后续学员实验顺利

# %% [markdown]
# * 问题一：对于sobel_test.cpp文件路径的提取

# %% [markdown]
# 在进行C仿真的时候，由于需要将最终的结果写入imgo.txt文件夹中，所以需要保证文件读取的路径是正确的，这里我的正确路径如下

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20154345.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20154345.png)

# %% [markdown]
# 如果路径不正确会产生如下报错

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20153832.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20153832.png)

# %% [markdown]
# 修改为如上正确地址后即可仿真成功，如下图

# %% [markdown]
# ![C%E4%BB%BF%E7%9C%9F%E6%88%90%E5%8A%9F.png](attachment:C%E4%BB%BF%E7%9C%9F%E6%88%90%E5%8A%9F.png)

# %% [markdown]
# * 问题二：顶层函数的选择

# %% [markdown]
# 在Create Project第一步Project name 选择顶层函数时有以下几个选项

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20151419.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20151419.png)

# %% [markdown]
# 这个时候，我们需要选择sobel作为顶层函数，否则在后面综合的过程中会报错，如下图

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20153827.png](attachment:%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE%202023-07-18%20153827.png)

# %% [markdown]
# 选择sobel作为顶层函数后即可解决

# %% [markdown]
# ![C%E7%BB%BC%E5%90%88%E6%88%90%E5%8A%9F.png](attachment:C%E7%BB%BC%E5%90%88%E6%88%90%E5%8A%9F.png)
